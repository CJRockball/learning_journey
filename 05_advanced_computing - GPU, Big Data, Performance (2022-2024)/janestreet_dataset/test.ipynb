# %%
from dask.distributed import Client, LocalCluster
import dask.dataframe as dd
from dask.distributed import LocalCluster

# %%
cluster = LocalCluster()
client = Client()
# Out:
# /home/patrick/Python/timeseries/weather/.venv/lib/python3.10/site-packages/distributed/node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 44809 instead
#   warnings.warn(
# /home/patrick/Python/timeseries/weather/.venv/lib/python3.10/site-packages/distributed/node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 36639 instead
#   warnings.warn(
